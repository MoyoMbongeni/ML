# %% [markdown]
# <a href="https://colab.research.google.com/github/MoyoMbongeni/ML/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Help from Chat-GPT

# %%
# =====================================================
# ECG Noise Detection & Severity Ranking
# SVM (feature-based) vs CNN (raw-signal, multi-label)
# =====================================================

import numpy as np
import pywt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, hamming_loss

# %%
np.random.seed(42)

def simulate_ecg(noise_type, length=1800):
    t = np.linspace(0, 5, length)
    base = np.sin(2*np.pi*1.2*t)

    if noise_type == 'BW':
        base += 0.6 * np.sin(2*np.pi*0.2*t)
    if noise_type == 'MA':
        base += 0.3 * np.random.randn(length)
    if noise_type == 'EM':
        base += 0.5 * np.sign(np.sin(2*np.pi*0.5*t))

    return base

labels = ['BW', 'MA', 'EM']
X, Y = [], []

for _ in range(300):
    sig = np.zeros(1800)
    y = [0, 0, 0]

    for i, n in enumerate(labels):
        if np.random.rand() > 0.5:
            sig += simulate_ecg(n)
            y[i] = 1

    sig = (sig - sig.min()) / (sig.max() - sig.min() + 1e-8)
    X.append(sig)
    Y.append(y)

X = np.array(X)
Y = np.array(Y)

# %%
def dwt_features(sig):
    coeffs = pywt.wavedec(sig, 'db4', level=3)
    feats = []
    for c in coeffs:
        feats.append(np.sum(c**2))
        feats.append(np.std(c))
    return feats  # 8 features

def terma_features(sig, fs=360):
    sq = sig**2
    short = int(0.05*fs)
    long = int(0.2*fs)
    ma_s = np.convolve(sq, np.ones(short)/short, 'same')
    ma_l = np.convolve(sq, np.ones(long)/long, 'same')
    terma = ma_s - ma_l
    return [np.mean(terma), np.std(terma), np.sum(terma > np.mean(terma))]

X_svm = np.array([dwt_features(x) + terma_features(x) for x in X])

# %%
X_cnn = X.reshape(-1, 1800, 1)

# %%
import numpy as np
import pywt
from sklearn.model_selection import train_test_split

np.random.seed(42)

def simulate_ecg(noise_type, length=1800):
    t = np.linspace(0, 5, length)
    base = np.sin(2*np.pi*1.2*t)

    if noise_type == 'BW':
        base += 0.6 * np.sin(2*np.pi*0.2*t)
    if noise_type == 'MA':
        base += 0.3 * np.random.randn(length)
    if noise_type == 'EM':
        base += 0.5 * np.sign(np.sin(2*np.pi*0.5*t))

    return base

labels = ['BW', 'MA', 'EM']
X, Y = [], []

for _ in range(300):
    sig = np.zeros(1800)
    y = [0, 0, 0]

    for i, n in enumerate(labels):
        if np.random.rand() > 0.5:
            sig += simulate_ecg(n)
            y[i] = 1

    sig = (sig - sig.min()) / (sig.max() - sig.min() + 1e-8)
    X.append(sig)
    Y.append(y)

X = np.array(X)
Y = np.array(Y)

def dwt_features(sig):
    coeffs = pywt.wavedec(sig, 'db4', level=3)
    feats = []
    for c in coeffs:
        feats.append(np.sum(c**2))
        feats.append(np.std(c))
    return feats

def terma_features(sig, fs=360):
    sq = sig**2
    short = int(0.05*fs)
    long = int(0.2*fs)
    ma_s = np.convolve(sq, np.ones(short)/short, 'same')
    ma_l = np.convolve(sq, np.ones(long)/long, 'same')
    terma = ma_s - ma_l
    return [np.mean(terma), np.std(terma), np.sum(terma > np.mean(terma))]

X_svm = np.array([dwt_features(x) + terma_features(x) for x in X])

X_cnn = X.reshape(-1, 1800, 1)

X_train_cnn, X_temp_cnn, Y_train, Y_temp = train_test_split(
    X_cnn, Y, test_size=0.30, random_state=42)

X_val_cnn, X_test_cnn, Y_val, Y_test = train_test_split(
    X_temp_cnn, Y_temp, test_size=0.50, random_state=42)

X_train_svm, X_temp_svm, _, _ = train_test_split(
    X_svm, Y, test_size=0.30, random_state=42)

X_val_svm, X_test_svm, _, _ = train_test_split(
    X_temp_svm, Y_temp, test_size=0.50, random_state=42)

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

svm = OneVsRestClassifier(
    SVC(kernel='rbf', C=1.0, gamma='scale')
)
svm.fit(X_train_svm, Y_train)
# Out:
# OneVsRestClassifier(estimator=SVC())

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, Dense
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf

cnn = Sequential([
    Conv1D(32, 7, activation='relu', input_shape=(1800,1)),
    Conv1D(64, 5, activation='relu'),
    Conv1D(64, 3, activation='relu'),
    GlobalAveragePooling1D(),
    Dense(32, activation='relu'),
    Dense(3, activation='sigmoid')
])

cnn.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss='binary_crossentropy'
)

cnn.fit(
    X_train_cnn, Y_train,
    validation_data=(X_val_cnn, Y_val),
    epochs=50,
    batch_size=32,
    callbacks=[EarlyStopping(patience=5, restore_best_weights=True)],
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.6906 - val_loss: 0.6851
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6860 - val_loss: 0.6841
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6810 - val_loss: 0.6854
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6809 - val_loss: 0.6821
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6777 - val_loss: 0.6767
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6801 - val_loss: 0.6757
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6690 - val_loss: 0.6683
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6568 - val_loss: 0.6509
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6455 - val_loss: 0.6433
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6121 - val_loss: 0.6149
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6079 - val_loss: 0.6037
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.5916 - val_loss: 0.5954
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5748 - val_loss: 0.5940
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5877 - val_loss: 0.5840
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5744 - val_loss: 0.5637
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5682 - val_loss: 0.5529
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5525 - val_loss: 0.5478
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5417 - val_loss: 0.5274
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5332 - val_loss: 0.5123
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5047 - val_loss: 0.5185
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5022 - val_loss: 0.4812
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4781 - val_loss: 0.4830
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4887 - val_loss: 0.4579
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4563 - val_loss: 0.4146
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4308 - val_loss: 0.3931
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4136 - val_loss: 0.3907
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4091 - val_loss: 0.3751
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3868 - val_loss: 0.3704
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3776 - val_loss: 0.3587
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3817 - val_loss: 0.3202
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3646 - val_loss: 0.3291
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3503 - val_loss: 0.3007
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3314 - val_loss: 0.2932
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3297 - val_loss: 0.2766
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3185 - val_loss: 0.2824
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3181 - val_loss: 0.2785
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3264 - val_loss: 0.2626
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3112 - val_loss: 0.2630
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2904 - val_loss: 0.2406
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2811 - val_loss: 0.2522
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2831 - val_loss: 0.2316
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2864 - val_loss: 0.2223
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2549 - val_loss: 0.2195
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2717 - val_loss: 0.2201
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2805 - val_loss: 0.2260
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2679 - val_loss: 0.2956
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2843 - val_loss: 0.2006
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2546 - val_loss: 0.2094
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2467 - val_loss: 0.2033
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2558 - val_loss: 0.1980

# %%
def analyze_ecg_segment(signal, model):
    signal = (signal - signal.min()) / (signal.max() - signal.min() + 1e-8)
    pred = model.predict(signal.reshape(1,1800,1))[0]

    detected = {
        'baseline_wander': bool(pred[0] > 0.5),
        'muscle_artifact': bool(pred[1] > 0.5),
        'electrode_motion': bool(pred[2] > 0.5)
    }

    severity = {
        k: round(v*100,1)
        for k,v in zip(detected.keys(), pred)
        if v > 0.5
    }

    dominant = max(severity, key=severity.get) if severity else 'clean'
    quality = 'good' if sum(pred) < 0.5 else 'moderate' if sum(pred) < 1.5 else 'poor'

    return {
        'detected_noises': detected,
        'severity_scores': severity,
        'dominant_noise': dominant,
        'overall_quality': quality
    }
